# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # 1. You were recently hired as a business analyst in a top sports company. The senior management team has asked you to come up with metrics with which they can gauge which team will win the upcoming La Liga cup (Football tournament). The given data set contains information on all the teams that have so far participated in all the past tournaments. It has data about how many goals each team scored, conceded; how many times they came within the first 6 positions, how many seasons they have qualified, their best position in the past, etc. You are required to do the following:

# %%
df=pd.read_csv('Laliga.csv',header=1,index_col=0)
df.head()
# Out:
#                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1        Real Madrid       86   4385        2762     1647        552
# 2          Barcelona       86   4262        2762     1581        573
# 3    Atletico Madrid       80   3442        2614     1241        598
# 4           Valencia       82   3386        2664     1187        616
# 5    Athletic Bilbao       86   3368        2762     1209        633
#
#     GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 1         563     5947         3140       33        23     8      8     3
# 2         608     5900         3114       25        25    12     12     4
# 3         775     4534         3309       10         8    16      9     7
# 4         861     4398         3469        6         6    10     11    10
# 5         920     4631         3700        8         7    10      5     8
#
#     Sixth   T    Debut Since/LastApp  BestPosition
# Pos
# ...

# %%
df.shape
# Out:
# (61, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 1 to 61
# Data columns (total 19 columns):
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           61 non-null object
# GamesPlayed      61 non-null object
# GamesWon         61 non-null object
# GamesDrawn       61 non-null object
# GamesLost        61 non-null object
# GoalsFor         61 non-null object
# GoalsAgainst     61 non-null object
# Champion         61 non-null object
# Runner-up        61 non-null object
# Third            61 non-null object
# Fourth           61 non-null object
# Fifth            61 non-null object
# Sixth            61 non-null object
# T                61 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: int64(2), object(17)
# memory usage: 9.5+ KB

# %%
df[60:].replace('-',0,inplace=True)
df.tail()
# Out:
# C:\Anaconda\envs\datascience\lib\site-packages\pandas\core\frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)
#                  Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 57              Xerez        1     34          38        8         10
# 58             Condal        1     22          30        7          8
# 59    Atletico Tetuan        1     19          30        7          5
# 60   Cultural Leonesa        1     14          30        5          4
# 61             Girona        1      0           0        0          0
#
#     GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 57         20       38           66        -         -     -      -     -
# 58         15       37           57        -         -     -      -     -
# ...

# %%
df['Points']=df['Points'].astype(int)

# %%
df['Points'].dtype
# Out:
# dtype('int32')

# %%
df1=df.replace('-',0)

# %%
df1.head()
# Out:
#                 Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1        Real Madrid       86    4385        2762     1647        552
# 2          Barcelona       86    4262        2762     1581        573
# 3    Atletico Madrid       80    3442        2614     1241        598
# 4           Valencia       82    3386        2664     1187        616
# 5    Athletic Bilbao       86    3368        2762     1209        633
#
#     GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 1         563     5947         3140       33        23     8      8     3
# 2         608     5900         3114       25        25    12     12     4
# 3         775     4534         3309       10         8    16      9     7
# 4         861     4398         3469        6         6    10     11    10
# 5         920     4631         3700        8         7    10      5     8
#
#     Sixth   T    Debut Since/LastApp  BestPosition
# Pos
# ...

# %%
def datatype(col):
    for i in col:
        df1[i]=df1[i].astype(int)

# %%
columns=['Seasons','Points','GamesPlayed','GamesWon','GamesDrawn','GamesLost','GoalsFor','GoalsAgainst',
         'Champion','Runner-up','Third','Fourth','Fifth','Sixth','T']

# %%
datatype(columns)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 1 to 61
# Data columns (total 19 columns):
# Team             61 non-null object
# Seasons          61 non-null int32
# Points           61 non-null int32
# GamesPlayed      61 non-null int32
# GamesWon         61 non-null int32
# GamesDrawn       61 non-null int32
# GamesLost        61 non-null int32
# GoalsFor         61 non-null int32
# GoalsAgainst     61 non-null int32
# Champion         61 non-null int32
# Runner-up        61 non-null int32
# Third            61 non-null int32
# Fourth           61 non-null int32
# Fifth            61 non-null int32
# Sixth            61 non-null int32
# T                61 non-null int32
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: int32(15), int64(1), object(3)
# memory usage: 6.0+ KB

# %%
df1['Debut']=df1['Debut'].apply(lambda x: x.split('-')[0])
df1['Since/LastApp']=df1['Since/LastApp'].apply(lambda x: x.split('-')[0])

# %%
df1
# Out:
#                     Team  Seasons  Points  GamesPlayed  GamesWon  GamesDrawn  \
# Pos
# 1            Real Madrid       86    4385         2762      1647         552
# 2              Barcelona       86    4262         2762      1581         573
# 3        Atletico Madrid       80    3442         2614      1241         598
# 4               Valencia       82    3386         2664      1187         616
# 5        Athletic Bilbao       86    3368         2762      1209         633
# 6                Sevilla       73    2819         2408       990         531
# 7               Espanyol       82    2792         2626       948         608
# 8          Real Sociedad       70    2573         2302       864         577
# 9               Zaragoza       58    2109         1986       698         522
# 10            Real Betis       51    1884         1728       606         440
# 11   Deportivo La Coruna       45    1814         1530       563         392
# ...

# %%
df1['Debut']=df1['Debut'].astype(int)
df1['Since/LastApp']=df1['Since/LastApp'].astype(int)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61 entries, 1 to 61
# Data columns (total 19 columns):
# Team             61 non-null object
# Seasons          61 non-null int32
# Points           61 non-null int32
# GamesPlayed      61 non-null int32
# GamesWon         61 non-null int32
# GamesDrawn       61 non-null int32
# GamesLost        61 non-null int32
# GoalsFor         61 non-null int32
# GoalsAgainst     61 non-null int32
# Champion         61 non-null int32
# Runner-up        61 non-null int32
# Third            61 non-null int32
# Fourth           61 non-null int32
# Fifth            61 non-null int32
# Sixth            61 non-null int32
# T                61 non-null int32
# Debut            61 non-null int32
# Since/LastApp    61 non-null int32
# BestPosition     61 non-null int64
# dtypes: int32(17), int64(1), object(1)
# memory usage: 5.5+ KB

# %% [markdown]
# 1.	Which are the teams which started playing between 1930-1980?

# %%
df1['Team'][(df1['Debut'] >= 1930) & (df1['Debut'] <= 1980)]
# Out:
# Pos
# 4                Valencia
# 6                 Sevilla
# 9                Zaragoza
# 10             Real Betis
# 11    Deportivo La Coruna
# 12             Celta Vigo
# 13             Valladolid
# 15         Sporting Gijon
# 16                Osasuna
# 17                 Malaga
# 18                 Oviedo
# 19               Mallorca
# 20             Las Palmas
# 22                Granada
# 23         Rayo Vallecano
# 24                  Elche
# 26               Hercules
# 27               Tenerife
# 28                 Murcia
# 29                 Alaves
# 30                Levante
# 31              Salamanca
# 32               Sabadell
# 33                  Cadiz
# 35              Castellon
# 38                Cordoba
# 40             Recreativo
# 41              Burgos CF
# 42             Pontevedra
# 47              Gimnastic
# 50               Alcoyano
# 51                   Jaen
# 53             AD Almeria
# 55                 Lleida
# 58                 Condal
# ...

# %% [markdown]
# 2.	Which are the top 5 teams in terms of points?

# %%
df1['Points']=df1['Points'].sort_values(ascending=False)
df1[['Team','Points']].head(5)
# Out:
#                 Team  Points
# Pos
# 1        Real Madrid    4385
# 2          Barcelona    4262
# 3    Atletico Madrid    3442
# 4           Valencia    3386
# 5    Athletic Bilbao    3368

# %% [markdown]
# 3.	What is the distribution of the winning percentage for all teams? Which teams are in the top 5 in terms of winning percentage? (Winning percentage= (GamesWon / GamesPlayed)*100)

# %%
df1['Winning_Percent']=(df1['GamesWon']/df1['GamesPlayed'])*100

# %%
df1[['Team','Winning_Percent']].head()
# Out:
#                 Team  Winning_Percent
# Pos
# 1        Real Madrid        59.630702
# 2          Barcelona        57.241130
# 3    Atletico Madrid        47.475134
# 4           Valencia        44.557057
# 5    Athletic Bilbao        43.772629

# %%
sns.kdeplot(df1['Winning_Percent'])
# Out:
# C:\Anaconda\envs\datascience\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Anaconda\envs\datascience\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
df1['Winning_Percent'].plot(kind='hist')

# %%
df1['Winning_Percent'].sort_values(ascending=False)
df1[['Team','Winning_Percent']].head(5)
# Out:
#                 Team  Winning_Percent
# Pos
# 1        Real Madrid        59.630702
# 2          Barcelona        57.241130
# 3    Atletico Madrid        47.475134
# 4           Valencia        44.557057
# 5    Athletic Bilbao        43.772629

# %%
df1['Winning_Percent'].mean()
# Out:
# 31.364789990145002

# %%
df1['Winning_Percent'].median()
# Out:
# 30.49172226340499

# %% [raw]
# Since we observe that mean and median are almost the same and hence it follows a normal distribution.

# %% [markdown]
# 4) Is there a significant difference in the winning percentage for teams which have attained a best position between 1-3 and those teams which have had a best position between 4-7.

# %% [raw]
# Ho : The avg mean of Winning Percentage of df_g1 = The avg mean of Winning Percentage of df_g2
# Ha : The avg mean of Winning Percentage of df_g1 != The avg mean of Winning Percentage of df_g2

# %%
df_g1=df1['Winning_Percent'][(df1['BestPosition'] >=1) & (df1['BestPosition'] <=3)]

# %%
df_g1.head()
# Out:
# Pos
# 1    59.630702
# 2    57.241130
# 3    47.475134
# 4    44.557057
# 5    43.772629
# Name: Winning_Percent, dtype: float64

# %%
df_g2=df1['Winning_Percent'][(df1['BestPosition'] >=4) & (df1['BestPosition'] <=7)]

# %%
df_g2.head()
# Out:
# Pos
# 12    34.511190
# 13    31.582538
# 16    32.321700
# 17    31.075697
# 22    29.380054
# Name: Winning_Percent, dtype: float64

# %% [raw]
# We do test of mean as we have one numeric and one categorical column with 2 groups :

# %% [raw]
# Shapiro Test of Normality :

# %%
from scipy.stats import norm,ttest_1samp, ttest_ind, mannwhitneyu, levene, shapiro, bartlett, wilcoxon

# %%
shapiro(df_g1)
# Out:
# (0.8252524733543396, 0.003532945876941085)

# %%
shapiro(df_g2)
# Out:
# (0.9436671733856201, 0.2809881269931793)

# %% [raw]
# The second group df_g2 is normally distribution as it  passes the normality test.

# %% [raw]
# Bartlett Test of Variance :

# %%
bartlett(df_g1,df_g2)
# Out:
# BartlettResult(statistic=32.093841690196015, pvalue=1.4690223883518985e-08)

# %% [raw]
# The groups have failed the test of variance.

# %% [raw]
# Mannwhitneyu Test of Mean :

# %%
mannwhitneyu(df_g1,df_g2)
# Out:
# MannwhitneyuResult(statistic=11.0, pvalue=4.1876636593687686e-07)

# %% [raw]
# It has failed manwhitneyu Test of Mean so we reject the Null Hypothesis and therefore we conclude that there is a significant difference between the average winning percentage of both the groups.

# %%
df_g1.mean()
# Out:
# 39.67412368466112

# %%
df_g2.mean()
# Out:
# 30.291020220767194

# %% [raw]
# There is a good difference between the mean of the two groups.

# %% [markdown]
# # 2. A study was done to measure the blood pressure of 60 year old women with glaucoma. A random sample of 200 60-year old women with glaucoma was chosen. The mean of the systolic blood pressure in the sample was 140 mm Hg and the standard deviation was 25 mm Hg.

# %%
mu=140
n=200
sd=25
sample=np.random.randn(200)
sample1=(sample*sd)+mu
sample1
# Out:
# array([142.86443921, 141.03038189, 192.2255659 ,  94.680683  ,
#        170.9314453 , 147.57777587, 148.51678089, 138.11175275,
#        125.76636241, 176.61439278, 143.10414517, 188.00244343,
#        141.68776082, 111.51272209, 133.86650637, 180.06539229,
#        117.19071476, 155.5267801 , 152.45326226, 176.24946047,
#        129.8519235 , 124.46842373, 166.64104895, 143.41149918,
#        110.5477228 , 144.5480914 , 166.46974723, 103.8638622 ,
#        137.40155714, 150.35661438, 129.56569734, 130.32665351,
#        150.58597952, 171.53249885, 150.96618921, 149.83534297,
#         99.24256033, 147.79126067, 117.44321422, 155.91911939,
#        137.36140454,  93.64402193, 134.0504716 , 103.90642949,
#        147.49942873,  84.95714857, 157.41336551, 152.65557045,
#        141.06013147, 103.86847867, 110.21287322, 144.51846809,
#        189.98663787, 140.10451517, 126.77263866, 132.94143202,
#        135.21797596, 154.8440824 , 128.69835835, 111.11219953,
# ...

# %% [markdown]
# a) Calculate the estimated standard error of the sample mean? What does the standard error indicate?

# %%
std_err=sd/np.sqrt(n)
print('Standard Error : ',std_err)
# Out:
# Standard Error :  1.7677669529663687

# %% [markdown]
# b)	Estimate a 95% confidence interval for the true mean blood pressure for all 60-year old women with glaucoma.

# %%
n=200
LI1=mu-(1.96*sd)/np.sqrt(n)
UI1=mu+(1.96*sd)/np.sqrt(n)
print('95% Confidence Interval : (',LI1,',',UI1,')')
# Out:
# 95% Confidence Interval : ( 136.5351767721859 , 143.4648232278141 )

# %% [markdown]
# c)	Assume that instead of 200, a random sample of only 100 60-year old women with glaucoma was chosen. The sample mean and standard deviation estimates are the same as those in the original study. What is the estimated 95% confidence interval for the true mean blood pressure?

# %%
n=100
LI2=mu-(1.96*sd)/np.sqrt(n)
UI2=mu+(1.96*sd)/np.sqrt(n)
print('95% Confidence Interval : (',LI2,',',UI2,')')
# Out:
# 95% Confidence Interval : ( 135.1 , 144.9 )

# %% [markdown]
# d)	Which of the two above intervals are wider?

# %%
Interval_200samp= UI1-LI1
print(Interval_200samp)
Interval_100samp= UI2-LI2
print(Interval_100samp)
# Out:
# 6.929646455628188
# 9.800000000000011

# %% [raw]
# Hence Second Interval with n=100 is wider.

# %% [markdown]
# e)	Explain in non-technical terms why the estimated standard error of a sample mean tends to decrease with an increase in sample size.

# %% [raw]
# Standard Error formula is  :
#
# std_err=sigma/np.sqrt(n)
#
# As you increase the sample size, the standard error of the mean will become smaller. With bigger sample sizes, the sample mean becomes a more accurate estimate of the parametric mean, so the standard error of the mean becomes smaller. Note that it's a function of the square root of the sample size; for example, to make the standard error half as big, you'll need four times as many observations.

# %% [markdown]
# # 3. Par Inc., is a major manufacturer of golf equipment. Management believes that Par’s market share could be increased with the introduction of a cut-resistant, longer-lasting golf ball. Therefore, the research group at Par has been investigating a new golf ball coating designed to resist cuts and provide a more durable ball. The tests with the coating have been promising.

# %%
df=pd.read_csv('Golf.csv')

# %%
df.head()
# Out:
#    Current  New
# 0      264  277
# 1      261  269
# 2      267  263
# 3      272  266
# 4      258  262

# %%
df.shape
# Out:
# (40, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
# Current    40 non-null int64
# New        40 non-null int64
# dtypes: int64(2)
# memory usage: 720.0 bytes

# %% [markdown]
# 1.	Formulate and present the rationale for a hypothesis test that Par could use to compare the driving distances of the current and new golf balls.

# %% [raw]
# Hypothesis Testing :
#
# Ho : The average of driving distance of Current balls = The average driving distance of New balls
# Ha : The average of driving distance of Current balls != The average driving distance of New balls

# %% [raw]
# Two Sample ttest :

# %%
shapiro(df['Current'])
# Out:
# (0.9707046747207642, 0.378787100315094)

# %%
shapiro(df['New'])
# Out:
# (0.9678263664245605, 0.3064655363559723)

# %% [raw]
# As both the groups are normally distributed we perform levene test :

# %%
levene(df['Current'],df['New'])
# Out:
# LeveneResult(statistic=0.2553238291765741, pvalue=0.6147759523331309)

# %% [raw]
# As both the groups pass the Levene variance test. Hence we perform ttest

# %%
ttest_ind(df['Current'],df['New'])
# Out:
# Ttest_indResult(statistic=1.3283615935245678, pvalue=0.18793228491854663)

# %% [raw]
# Since the p_value > 0.05 hence we fail to reject the Null Hypothesis.
# Therefore, The average of driving distance of Current balls = The average driving distance of New balls
# Also we can say that there is no significant difference between the average driving distances of Current and New balls.

# %% [markdown]
# 2.	Analyze the data to provide the hypothesis testing conclusion. What is the p-value for your test? What is your recommendation for Par Inc.?

# %% [raw]
# By the above analysis we can recommend Par Inc. to proceed with the production of the New cut resistant , long lasting golf balls.
# We have statiscally proven that the average driving distance of the Current and coated New balls are significantly same with an accepted error of just 5%.

# %% [markdown]
# 3.	What is the 95% confidence interval for the population mean of each model, and what is the 95% confidence interval for the difference between the means of the two population?

# %%
n=40
mu1=np.mean(df['Current'])
sd1=(df['Current']).std()
print(mu1)
print(sd1)
# Out:
# 270.275
# 8.752984838884597

# %%
LI1=mu1-(1.96*sd1)/np.sqrt(n)
UI1=mu1+(1.96*sd1)/np.sqrt(n)
print('95% Confidence Interval for Current Balls : (',LI1,',',UI1,')')
# Out:
# 95% Confidence Interval for Current Balls : ( 267.5624218952518 , 272.98757810474814 )

# %%
n=40
mu2=np.mean(df['New'])
sd2=df['New'].std()
print(mu2)
print(sd2)
# Out:
# 267.5
# 9.896904462947894

# %%
LI2=mu2-(1.96*sd2)/np.sqrt(n)
UI2=mu2+(1.96*sd2)/np.sqrt(n)
print('95% Confidence Interval for New Balls : (',LI2,',',UI2,')')
# Out:
# 95% Confidence Interval for New Balls : ( 264.43291753097594 , 270.56708246902406 )

# %%
mu1-mu2
sd1-sd2
# Out:
# -1.1439196240632974

# %%
LI=(mu1-mu2)-(1.96*np.sqrt((sd1**2 + sd2**2)/n))
UI=(mu1-mu2)+(1.96*np.sqrt((sd1**2 + sd2**2)/n))
print('95% confidence interval for the difference between the means of the two population : (',LI,',',UI,')')
# Out:
# 95% confidence interval for the difference between the means of the two population : ( -1.3195176573259557 , 6.86951765732591 )
